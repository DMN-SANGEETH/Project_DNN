# %%
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D,Dropout,BatchNormalization

model=Sequential()
model.add(Conv2D(256,(3,3),input_shape=[224,224,1],kernel_initializer='orthogonal'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(128,(3,3),kernel_initializer='orthogonal'))
#model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64,(3,3)))
#model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(32,activation='relu'))
model.add(Dense(2,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

model.summary()
# Out:
# C:\Users\User\anaconda3\envs\new\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 256)     2560
#
#  batch_normalization (BatchN  (None, 222, 222, 256)    1024
#  ormalization)
#
#  activation (Activation)     (None, 222, 222, 256)     0
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 256)    0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 128)     295040
#
#  activation_1 (Activation)   (None, 109, 109, 128)     0
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 128)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 64)        73792
#
#  activation_2 (Activation)   (None, 52, 52, 64)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 43264)             0
#
#  dropout (Dropout)           (None, 43264)             0
#
#  dense (Dense)               (None, 32)                1384480
#
#  dense_1 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 1,756,962
# Trainable params: 1,756,450
# Non-trainable params: 512
# _________________________________________________________________

# %%
model.load_weights('CNN_MODEL.h5')

# %%
import os
import cv2
import numpy as np

test_path=r'Folder/Resize_Patient_testing'
img_names=os.listdir(test_path)
category_dict={0:'Normal',1:'Patient'}

for img_name in img_names:
    img=cv2.imread(os.path.join(test_path,img_name))
    
    h,w=img.shape[0:2] #height and width eka

     #preprocessing (As done for the training images)
    #test_img=cv2.resize(img,(224,224))
    #test_img=cv2.cvtColor(test_img,cv2.COLOR_BGR2GRAY)
    #test_img=test_img/255
    #test_img=test_img.reshape(1,224,224,1) #neural netowrk eka 4d input ekak illna nisa 4d krgnnwa image eka. 
    #mul tyna 1 thmi 1 image ekak nisa. multiple image tbba nam aulk na 1k image ekk nisa manually denwa.
    
    
    
    #img=cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            # blur
    blur = cv2.GaussianBlur(gray, (0,0), sigmaX=33, sigmaY=33)

            # divide
    divide = cv2.divide(gray, blur, scale=255)

            # otsu threshold
    thresh = cv2.threshold(divide, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)[1]

            # apply morphology
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))
    morph = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)

    test_img=cv2.resize(thresh,(224,224))
    test_img=test_img/255
    test_img=test_img.reshape(1,224,224,1)
    
    
    
    
    
    
    results=model.predict(test_img)
    label=np.argmax(results,axis=1)[0] #probability 2d array eken wedi eka gnnwa.
    acc=int(np.max(results,axis=1)[0]*100)
    
    print(results,label,category_dict[label],acc) 
    
    img[0:50,0:w]=[0,255,0]
    cv2.putText(img,category_dict[label],(20,40),cv2.FONT_HERSHEY_SIMPLEX,1.5,(255,255,255),2)
    cv2.putText(img,str(acc)+'%',(120,40),cv2.FONT_HERSHEY_SIMPLEX,1.5,(255,255,255),2)
    
    cv2.imshow('LIVE',img)
    k=cv2.waitKey(300)
    if(k==27):
        break
cv2.destroyAllWindows()
# Out:
# [[0.6796609 0.3203391]] 0 Normal 67
# [[2.7027279e-06 9.9999726e-01]] 1 Patient 99
# [[0.00109191 0.99890804]] 1 Patient 99
# [[0.00644699 0.99355304]] 1 Patient 99
# [[0.11153156 0.88846844]] 1 Patient 88
# [[0.0019482  0.99805176]] 1 Patient 99
# [[0.00738098 0.992619  ]] 1 Patient 99
# [[0.09863971 0.90136033]] 1 Patient 90
# [[0.09601322 0.9039868 ]] 1 Patient 90
# [[0.00134066 0.9986594 ]] 1 Patient 99
# [[5.521294e-04 9.994479e-01]] 1 Patient 99
